# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import KFold
import warnings
import time
import sys
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import BayesianRidge
warnings.simplefilter(action='ignore', category=FutureWarning)
import gc

# %%
external2_train = pd.read_csv('../3_cleandata/train_df_elo17.csv')
external2_test = pd.read_csv('../3_cleandata/test_df_elo17.csv')

# %%
print(list(external2_train.columns))
# Out:
# ['first_active_month', 'feature_1', 'feature_2', 'feature_3', 'target', 'outliers', 'quarter', 'elapsed_time', 'days_feature_1', 'days_feature_1_ratio', 'days_feature_2', 'days_feature_2_ratio', 'days_feature_3', 'days_feature_3_ratio', 'features_sum', 'features_mean', 'features_max', 'features_min', 'features_var', 'features_prod', 'new_subsector_id_nunique', 'new_merchant_id_nunique', 'new_merchant_category_id_nunique', 'new_month_mean', 'new_month_min', 'new_month_max', 'new_hour_nunique', 'new_hour_mean', 'new_hour_min', 'new_hour_max', 'new_weekofyear_nunique', 'new_weekofyear_mean', 'new_weekofyear_min', 'new_weekofyear_max', 'new_weekday_mean', 'new_weekday_min', 'new_weekday_max', 'new_day_nunique', 'new_day_mean', 'new_day_min', 'new_day_max', 'new_purchase_amount_sum', 'new_purchase_amount_max', 'new_purchase_amount_min', 'new_purchase_amount_mean', 'new_purchase_amount_var', 'new_purchase_amount_skew', 'new_installments_sum', 'new_installments_max', 'new_installments_mean', 'new_installments_var', 'new_installments_skew', 'new_purchase_date_max', 'new_purchase_date_min', 'new_month_lag_max', 'new_month_lag_min', 'new_month_lag_mean', 'new_month_lag_var', 'new_month_lag_skew', 'new_month_diff_mean', 'new_month_diff_var', 'new_month_diff_skew', 'new_weekend_mean', 'new_category_1_mean', 'new_category_2_mean', 'new_category_3_mean', 'new_card_id_size', 'new_card_id_count', 'new_price_mean', 'new_price_max', 'new_price_min', 'new_price_var', 'new_Christmas_Day_2017_mean', 'new_Christmas_Day_2017_sum', 'new_Children_day_2017_mean', 'new_Children_day_2017_sum', 'new_Black_Friday_2017_mean', 'new_Black_Friday_2017_sum', 'new_Mothers_Day_2018_mean', 'new_Mothers_Day_2018_sum', 'new_duration_mean', 'new_duration_min', 'new_duration_max', 'new_duration_var', 'new_duration_skew', 'new_amount_month_ratio_mean', 'new_amount_month_ratio_min', 'new_amount_month_ratio_max', 'new_amount_month_ratio_var', 'new_amount_month_ratio_skew', 'new_category_2_mean_mean', 'new_category_3_mean_mean', 'new_CLV', 'new_purchase_date_diff', 'new_purchase_date_average', 'new_purchase_date_uptonow', 'new_purchase_date_uptomin', 'hist_subsector_id_nunique', 'hist_merchant_id_nunique', 'hist_merchant_category_id_nunique', 'hist_month_nunique', 'hist_month_mean', 'hist_month_min', 'hist_month_max', 'hist_hour_nunique', 'hist_hour_mean', 'hist_hour_min', 'hist_hour_max', 'hist_weekofyear_nunique', 'hist_weekofyear_mean', 'hist_weekofyear_min', 'hist_weekofyear_max', 'hist_weekday_mean', 'hist_day_nunique', 'hist_day_mean', 'hist_day_min', 'hist_purchase_amount_sum', 'hist_purchase_amount_max', 'hist_purchase_amount_min', 'hist_purchase_amount_mean', 'hist_purchase_amount_var', 'hist_purchase_amount_skew', 'hist_installments_sum', 'hist_installments_max', 'hist_installments_mean', 'hist_installments_var', 'hist_installments_skew', 'hist_purchase_date_max', 'hist_purchase_date_min', 'hist_month_lag_max', 'hist_month_lag_min', 'hist_month_lag_mean', 'hist_month_lag_var', 'hist_month_lag_skew', 'hist_month_diff_max', 'hist_month_diff_min', 'hist_month_diff_mean', 'hist_month_diff_var', 'hist_month_diff_skew', 'hist_authorized_flag_mean', 'hist_weekend_mean', 'hist_category_1_mean', 'hist_category_2_mean', 'hist_category_3_mean', 'hist_card_id_size', 'hist_card_id_count', 'hist_price_sum', 'hist_price_mean', 'hist_price_max', 'hist_price_min', 'hist_price_var', 'hist_Christmas_Day_2017_mean', 'hist_Christmas_Day_2017_sum', 'hist_Mothers_Day_2017_mean', 'hist_Mothers_Day_2017_sum', 'hist_fathers_day_2017_mean', 'hist_fathers_day_2017_sum', 'hist_Children_day_2017_mean', 'hist_Children_day_2017_sum', 'hist_Valentine_Day_2017_mean', 'hist_Valentine_Day_2017_sum', 'hist_Black_Friday_2017_mean', 'hist_Black_Friday_2017_sum', 'hist_Mothers_Day_2018_mean', 'hist_Mothers_Day_2018_sum', 'hist_duration_mean', 'hist_duration_min', 'hist_duration_max', 'hist_duration_var', 'hist_duration_skew', 'hist_amount_month_ratio_mean', 'hist_amount_month_ratio_min', 'hist_amount_ ...

# %%
col2 = ['new_Christmas_Day_2017_mean', 'new_Christmas_Day_2017_sum', 'new_Children_day_2017_mean', 'new_Children_day_2017_sum', 'new_Black_Friday_2017_mean', 'new_Black_Friday_2017_sum', 'new_Mothers_Day_2018_mean', 'new_Mothers_Day_2018_sum','hist_Christmas_Day_2017_mean', 'hist_Christmas_Day_2017_sum', 'hist_Mothers_Day_2017_mean', 'hist_Mothers_Day_2017_sum', 'hist_fathers_day_2017_mean', 'hist_fathers_day_2017_sum', 'hist_Children_day_2017_mean', 'hist_Children_day_2017_sum', 'hist_Valentine_Day_2017_mean', 'hist_Valentine_Day_2017_sum', 'hist_Black_Friday_2017_mean', 'hist_Black_Friday_2017_sum', 'hist_Mothers_Day_2018_mean', 'hist_Mothers_Day_2018_sum']
external2_train = external2_train[col2]
external2_test = external2_test[col2]

# %%
internal_train = pd.read_csv('../3_cleandata/train_1.csv')
internal_test = pd.read_csv('../3_cleandata/test_1.csv')

# %%
print(list(internal_train.columns))
# Out:
# ['feature_1', 'feature_2', 'feature_3', 'elapsed_time', 'hist_transactions_count', 'hist_category_1_sum', 'hist_category_1_mean', 'hist_category_2_1.0_mean', 'hist_category_2_2.0_mean', 'hist_category_2_3.0_mean', 'hist_category_2_4.0_mean', 'hist_category_2_5.0_mean', 'hist_category_3_A_mean', 'hist_category_3_B_mean', 'hist_category_3_C_mean', 'hist_merchant_id_nunique', 'hist_merchant_category_id_nunique', 'hist_state_id_nunique', 'hist_city_id_nunique', 'hist_subsector_id_nunique', 'hist_purchase_amount_sum', 'hist_purchase_amount_mean', 'hist_purchase_amount_max', 'hist_purchase_amount_min', 'hist_purchase_amount_std', 'hist_installments_sum', 'hist_installments_mean', 'hist_installments_max', 'hist_installments_min', 'hist_installments_std', 'hist_purchase_month_mean', 'hist_purchase_month_max', 'hist_purchase_month_min', 'hist_purchase_month_std', 'hist_purchase_date_ptp', 'hist_purchase_date_min', 'hist_purchase_date_max', 'hist_month_lag_min', 'hist_month_lag_max', 'auth_transactions_count', 'auth_category_1_sum', 'auth_category_1_mean', 'auth_category_2_1.0_mean', 'auth_category_2_2.0_mean', 'auth_category_2_3.0_mean', 'auth_category_2_4.0_mean', 'auth_category_2_5.0_mean', 'auth_category_3_A_mean', 'auth_category_3_B_mean', 'auth_category_3_C_mean', 'auth_merchant_id_nunique', 'auth_merchant_category_id_nunique', 'auth_state_id_nunique', 'auth_city_id_nunique', 'auth_subsector_id_nunique', 'auth_purchase_amount_sum', 'auth_purchase_amount_mean', 'auth_purchase_amount_max', 'auth_purchase_amount_min', 'auth_purchase_amount_std', 'auth_installments_sum', 'auth_installments_mean', 'auth_installments_max', 'auth_installments_min', 'auth_installments_std', 'auth_purchase_month_mean', 'auth_purchase_month_max', 'auth_purchase_month_min', 'auth_purchase_month_std', 'auth_purchase_date_ptp', 'auth_purchase_date_min', 'auth_purchase_date_max', 'auth_month_lag_min', 'auth_month_lag_max', 'new_transactions_count', 'new_category_1_sum', 'new_category_1_mean', 'new_category_2_1.0_mean', 'new_category_2_2.0_mean', 'new_category_2_3.0_mean', 'new_category_2_4.0_mean', 'new_category_2_5.0_mean', 'new_category_3_A_mean', 'new_category_3_B_mean', 'new_category_3_C_mean', 'new_merchant_id_nunique', 'new_merchant_category_id_nunique', 'new_state_id_nunique', 'new_city_id_nunique', 'new_subsector_id_nunique', 'new_purchase_amount_sum', 'new_purchase_amount_mean', 'new_purchase_amount_max', 'new_purchase_amount_min', 'new_purchase_amount_std', 'new_installments_sum', 'new_installments_mean', 'new_installments_max', 'new_installments_min', 'new_installments_std', 'new_purchase_month_mean', 'new_purchase_month_max', 'new_purchase_month_min', 'new_purchase_month_std', 'new_purchase_date_ptp', 'new_purchase_date_min', 'new_purchase_date_max', 'new_month_lag_min', 'new_month_lag_max', 'month_lag_mean', 'month_lag_std', 'purchase_amount_count_mean', 'purchase_amount_count_std', 'purchase_amount_sum_mean', 'purchase_amount_sum_std', 'purchase_amount_mean_mean', 'purchase_amount_mean_std', 'purchase_amount_min_mean', 'purchase_amount_min_std', 'purchase_amount_max_mean', 'purchase_amount_max_std', 'purchase_amount_std_mean', 'purchase_amount_std_std', 'installments_count_mean', 'installments_count_std', 'installments_sum_mean', 'installments_sum_std', 'installments_mean_mean', 'installments_mean_std', 'installments_min_mean', 'installments_min_std', 'installments_max_mean', 'installments_max_std', 'installments_std_mean', 'installments_std_std', 'authorized_flag_sum', 'authorized_flag_mean', 'card_id', 'first_active_month']

# %%
internal_train.shape
# Out:
# (201917, 139)

# %%
external_test = pd.read_csv('../3_cleandata/test_ext1.csv')
external_train = pd.read_csv('../3_cleandata/train_ext1.csv')

# %%
target = pd.read_csv('../3_cleandata/target_int.csv',header= None)

# %%
external_train.shape
# Out:
# (201917, 215)

# %%
external_train.head()
# Out:
#   first_active_month  feature_1  feature_2  feature_3  target  outliers  \
# 0         2017-06-01   0.013145    0.00875   0.011430 -0.8203         0
# 1         2017-01-01   0.010710    0.01138   0.010284  0.3928         0
# 2         2016-08-01   0.010610    0.00875   0.010284  0.6880         0
# 3         2017-09-01   0.010710    0.01417   0.010284  0.1425         0
# 4         2017-11-01   0.008060    0.01417   0.010284 -0.1598         0
#
#    quarter  elapsed_time  days_feature_1  days_feature_1_ratio  ...  \
# 0        2           604            3020              0.008280  ...
# 1        1           755            3020              0.005300  ...
# 2        3           908            1816              0.002203  ...
# 3        3           512            2048              0.007812  ...
# 4        4           451             451              0.002218  ...
#
#    month_lag_min  category_1_mean  duration_mean  duration_min  duration_max  \
# 0           -7.0          0.00000        -13.470        -16.78         5.540
# 1          -11.0          0.08856        -16.160        -18.47         1.180
# 2          -11.0          0.00000        -15.220        -16.44        -9.305
# 3           -4.0          0.29880        -14.484        -16.92         2.562
# 4           -2.0          0.16830        -12.310        -16.72        13.760
#
#    amount_month_ratio_mean  amount_month_ratio_min  amount_month_ratio_max  \
# 0                 -0.11050                 -0.1330                 0.04584
# 1                 -0.11145                 -0.1283                 0.00815
# 2                 -0.12494                 -0.1301                -0.07690
# 3                 -0.11960                 -0.1384                 0.02124
# 4                 -0.10175                 -0.1377                 0.11380
#
#    CLV_ratio        CLV_sq
# 0   0.007045  108812.65000
# 1   0.000349   13576.58700
# 2   0.000562       7.21371
# 3   0.008454    1038.37830
# 4   0.071696   59269.74200
#
# [5 rows x 215 columns]

# %%
internal_train.head()
# Out:
#    feature_1  feature_2  feature_3  elapsed_time  hist_transactions_count  \
# 0   1.597335   0.338839   0.876431     -0.466376                 0.311084
# 1   0.754276  -0.992082  -1.140992      0.047738                 0.150070
# 2  -0.931842   0.338839  -1.140992      0.568661                -0.574497
# 3   0.754276   1.669759  -1.140992     -0.779611                      NaN
# 4  -1.774901   1.669759  -1.140992     -0.987299                -0.332975
#
#    hist_category_1_sum  hist_category_1_mean  hist_category_2_1.0_mean  \
# 0            -0.234615             -0.548342                  1.203092
# 1             0.011414              0.048638                  0.798033
# 2            -0.234615             -0.548342                 -1.024733
# 3                  NaN                   NaN                       NaN
# 4             0.134429              1.421691                 -1.024733
#
#    hist_category_2_2.0_mean  hist_category_2_3.0_mean  ...  \
# 0                 -0.209665                 -0.432998  ...
# 1                 -0.209665                 -0.432998  ...
# 2                 -0.209665                 -0.432998  ...
# 3                       NaN                       NaN  ...
# 4                 -0.209665                 -0.432998  ...
#
#    installments_min_mean  installments_min_std  installments_max_mean  \
# 0              -0.098800             -0.041617              -0.085851
# 1               0.252809              0.279891               0.288626
# 2              -0.116381             -0.081152              -0.127460
# 3                    NaN                   NaN                    NaN
# 4               0.569258              0.672080               0.413451
#
#    installments_max_std  installments_std_mean  installments_std_std  \
# 0             -0.053041              -0.024789             -0.035181
# 1              0.225142               0.202897              0.323511
# 2             -0.093761                    NaN                   NaN
# 3                   NaN                    NaN                   NaN
# 4              0.484505              -0.065333             -0.085980
#
#    authorized_flag_sum  authorized_flag_mean          card_id  \
# 0             1.667028              0.494966  C_ID_92a2005557
# 1             2.594044              0.657240  C_ID_3d0044924f
# 2            -0.408683              0.525447  C_ID_d639edf6cd
# 3            -0.045938              0.931856  C_ID_186d6a6901
# 4             0.467952              0.603368  C_ID_cdbd2c0db2
#
#    first_active_month
# 0          2017-06-01
# 1          2017-01-01
# 2          2016-08-01
# 3          2017-09-01
# 4          2017-11-01
#
# [5 rows x 139 columns]

# %%
cols = ['hist_Christmas_Day_2017_mean','hist_Christmas_Day_2017_sum', 'hist_Mothers_Day_2017_mean',
 'hist_Mothers_Day_2017_sum', 'hist_fathers_day_2017_mean', 'hist_fathers_day_2017_sum',
 'hist_Children_day_2017_mean', 'hist_Children_day_2017_sum', 'hist_Valentine_Day_2017_mean',
 'hist_Valentine_Day_2017_sum', 'hist_Black_Friday_2017_mean', 'hist_Black_Friday_2017_sum',
 'hist_Mothers_Day_2018_mean', 'hist_Mothers_Day_2018_sum', 'CLV_ratio',
 'CLV_sq', 'new_Christmas_Day_2017_mean', 'new_Christmas_Day_2017_sum',
 'new_Children_day_2017_mean', 'new_Children_day_2017_sum', 'new_Black_Friday_2017_mean','new_Black_Friday_2017_sum',
 'new_Mothers_Day_2018_mean', 'new_Mothers_Day_2018_sum',]

def joining_dataset(internal, external,external2,cols):
    combine = pd.concat([external2,internal,external[cols]] ,axis=1, join='inner')
    return combine

train = joining_dataset(internal= internal_train, external= external_train,external2 = external2_train, cols = cols)
test = joining_dataset(internal= internal_test, external= external_test,external2 = external2_test, cols = cols)

# %%
train.shape
# Out:
# (201917, 185)

# %%
test.shape
# Out:
# (123623, 185)

# %%
 _, i = np.unique(train.columns, return_index=True)

train =train.iloc[:, i]
print(train.shape)
 _, j = np.unique(test.columns, return_index=True)
test =test.iloc[:, j]
print(test.shape)
# Out:
# (201917, 163)
# (123623, 163)

# %%
#exclude the card_id and first_active month in the features 
features = [c for c in train.columns if c not in ['card_id', 'first_active_month']]
#create a list of categorical features 
categorical_feats = [c for c in features if 'feature_' in c]

# %%
print(len(features))
print(len(categorical_feats))
# Out:
# 161
# 3

# %%
#lightgbm configuration
param = {'num_leaves': 50,
         'min_data_in_leaf': 32, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.005,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "bagging_seed": 11,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "nthread": 4,
         "verbosity": -1}

# %%
folds = KFold(n_splits=10, shuffle=True, random_state=15)
oof = np.zeros(len(train))
predictions = np.zeros(len(test))
start = time.time()
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    print("fold n°{}".format(fold_))
    trn_data = lgb.Dataset(train.iloc[trn_idx][features], label=target.iloc[trn_idx], categorical_feature=categorical_feats)
    val_data = lgb.Dataset(train.iloc[val_idx][features], label=target.iloc[val_idx], categorical_feature=categorical_feats)

    num_round = 100000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 300)
    oof[val_idx] = clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    print(len(clf.feature_importance()))
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(mean_squared_error(oof, target)**0.5))
# Out:
# fold n°0
# /home/tung/miniconda3/envs/kaggle/lib/python3.7/site-packages/lightgbm/basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/tung/miniconda3/envs/kaggle/lib/python3.7/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 300 rounds.
# [100]	training's rmse: 3.7155	valid_1's rmse: 3.82853
# [200]	training's rmse: 3.63921	valid_1's rmse: 3.78374
# [300]	training's rmse: 3.58581	valid_1's rmse: 3.76206
# [400]	training's rmse: 3.54446	valid_1's rmse: 3.74807
# [500]	training's rmse: 3.5098	valid_1's rmse: 3.73998
# [600]	training's rmse: 3.48098	valid_1's rmse: 3.73375
# [700]	training's rmse: 3.45585	valid_1's rmse: 3.72843
# [800]	training's rmse: 3.43299	valid_1's rmse: 3.725
# [900]	training's rmse: 3.41125	valid_1's rmse: 3.72222
# [1000]	training's rmse: 3.39165	valid_1's rmse: 3.72001
# [1100]	training's rmse: 3.37358	valid_1's rmse: 3.7183
# [1200]	training's rmse: 3.35606	valid_1's rmse: 3.71737
# [1300]	training's rmse: 3.34024	valid_1's rmse: 3.71645
# [1400]	training's rmse: 3.32479	valid_1's rmse: 3.71559
# [1500]	training's rmse: 3.30993	valid_1's rmse: 3.71478
# [1600]	training's rmse: 3.29531	valid_1's rmse: 3.71406
# [1700]	training's rmse: 3.28161	valid_1's rmse: 3.71376
# [1800]	training's rmse: 3.26855	valid_1's rmse: 3.71319
# [1900]	training's rmse: 3.25532	valid_1's rmse: 3.71232
# [2000]	training's rmse: 3.24285	valid_1's rmse: 3.71241
# [2100]	training's rmse: 3.2307	valid_1's rmse: 3.71173
# [2200]	training's rmse: 3.21936	valid_1's rmse: 3.71132
# [2300]	training's rmse: 3.20807	valid_1's rmse: 3.71113
# [2400]	training's rmse: 3.19697	valid_1's rmse: 3.71099
# [2500]	training's rmse: 3.1862	valid_1's rmse: 3.71057
# [2600]	training's rmse: 3.17515	valid_1's rmse: 3.71062
# [2700]	training's rmse: 3.16471	valid_1's rmse: 3.7104
# [2800]	training's rmse: 3.15437	valid_1's rmse: 3.71036
# [2900]	training's rmse: 3.1448	valid_1's rmse: 3.71019
# [3000]	training's rmse: 3.13443	valid_1's rmse: 3.71005
# [3100]	training's rmse: 3.12426	valid_1's rmse: 3.71038
# [3200]	training's rmse: 3.11448	valid_1's rmse: 3.71032
# [3300]	training's rmse: 3.10479	valid_1's rmse: 3.71013
# Early stopping, best iteration is:
# [3025]	training's rmse: 3.13182	valid_1's rmse: 3.70996
# 161
# fold n°1
# Training until validation scores don't improve for 300 rounds.
# [100]	training's rmse: 3.72445	valid_1's rmse: 3.75709
# [200]	training's rmse: 3.64762	valid_1's rmse: 3.71577
# [300]	training's rmse: 3.59277	valid_1's rmse: 3.69505
# [400]	training's rmse: 3.55133	valid_1's rmse: 3.68309
# [500]	training's rmse: 3.51735	valid_1's rmse: 3.67722
# [600]	training's rmse: 3.48735	valid_1's rmse: 3.67209
# [700]	training's rmse: 3.46151	valid_1's rmse: 3.66889
# [800]	training's rmse: 3.43798	valid_1's rmse: 3.6666
# [900]	training's rmse: 3.41668	valid_1's rmse: 3.66481
# [1000]	training's rmse: 3.39647	valid_1's rmse: 3.66392
# [1100]	training's rmse: 3.3783	valid_1's rmse: 3.66289
# [1200]	training's rmse: 3.3607	valid_1's rmse: 3.66235
# [1300]	training's rmse: 3.34386	valid_1's rmse: 3.66181
# [1400]	training's rmse: 3.32819	valid_1's rmse: 3.66168
# [1500]	training's rmse: 3.31315	valid_1's rmse: 3.66198
# [1600]	training's rmse: 3.29865	valid_1's rmse: 3.66191
# Early stopping, best iteration is:
# [1330]	training's rmse: 3.33914	valid_1's rmse: 3.66153
# 161
# fold n°2
# Training until validation scores don't improve for 300 rounds.
# [100]	training's rmse: 3.73004	valid_1's rmse: 3.69231
# [200]	training's rmse: 3.6525	valid_1's rmse: 3.65454
# [300]	training's rmse: 3.59813	valid_1's rmse: 3.63676
# [400]	training's rmse: 3.55601	valid_1's rmse: 3.62584
# [500]	training's rmse: 3.52192	valid_1's rmse: 3.61799
# [600]	training's rmse: 3.49238	valid_1's rmse: 3.61431
# [700]	training's rmse: 3.46673	valid_1's rmse: 3.61113
# [800]	training's rmse: 3.44406	valid_1's rmse: 3.60861
# [900]	training's rmse: 3.42267	valid_1's rmse: 3.60609
# [1000]	training's rmse: 3.40269	valid_1's rmse: 3.60422
# [1100]	training's rmse: 3.38446	valid_1's rmse: 3.60258
# [1200]	training's rmse: 3.36756	valid_1's rmse: 3.60148
# [1300]	training's rmse: 3.35137	valid_1's rmse: 3.60036
# [1400]	training's rmse: 3.33553	valid_1's rmse: 3.59938
# [1500]	training's rmse: 3.32078	valid_1's rmse: 3.59877
# [1600]	training's rmse: 3.30648	valid_1's rmse: 3.59834
# [1700]	training's rmse: 3.29316	valid_1's rmse: 3.598
# [1800]	training's rmse: 3.28008	valid_1's rmse: 3.59796
# [1900]	training's rmse: 3.26772	valid_1's rmse: 3.59761
# [2000]	training's rmse: 3.2553	valid_1's rmse: 3.59709
# [2100]	training's rmse: 3.24307	valid_1's rmse: 3.59713
# [2200]	training's rmse: 3.23161	valid_1's rmse: 3.59727
# [2300]	training's rmse: 3.21978	valid_1's rmse: 3.59703
# [2400]	training's rmse: 3.20876	valid_1's rmse: 3.59695
# [2500]	training's rmse: 3.19713	valid_1's rmse: 3.59661
# [2600]	training's rmse: 3.18622	valid_1's rmse: 3.59669
# [2700]	training's rmse: 3.17577	valid_1's rmse: 3.59671
# [2800]	training's rmse: 3.16495	valid_1's rmse: 3.59693
# Early stopping, best iteration is:
# [2529]	training's rmse: 3.19393	valid_1's rmse: 3.59646
# 161
# fold n°3
# Training until validation scores don't improve for 300 rounds.
# [100]	training's rmse: 3.72444	valid_1's rmse: 3.75111
# [200]	training's rmse: 3.64759	valid_1's rmse: 3.71463
# [300]	training's rmse: 3.59287	valid_1's rmse: 3.69471
# [400]	training's rmse: 3.55191	valid_1's rmse: 3.68171
# [500]	training's rmse: 3.51696	valid_1's rmse: 3.67401
# [600]	training's rmse: 3.48686	valid_1's rmse: 3.66933
# [700]	training's rmse: 3.46145	valid_1's rmse: 3.66562
# [800]	training's rmse: 3.43888	valid_1's rmse: 3.66271
# [900]	training's rmse: 3.41795	valid_1's rmse: 3.66005
# [1000]	training's rmse: 3.39816	valid_1's rmse: 3.65847
# [1100]	training's rmse: 3.38006	valid_1's rmse: 3.65688
# [1200]	training's rmse: 3.36306	valid_1's rmse: 3.65618
# [1300]	training's rmse: 3.3465	valid_1's rmse: 3.65524
# [1400]	training's rmse: 3.33067	valid_1's rmse: 3.65481
# [1500]	training's rmse: 3.31578	valid_1's rmse: 3.65451
# [1600]	training's rmse: 3.30143	valid_1's rmse: 3.65396
# [1700]	training's rmse: 3.28735	valid_1's rmse: 3.65367
# [1800]	training's rmse: 3.27351	valid_1's rmse: 3.65351
# [1900]	training's rmse: 3.26038	valid_1's rmse: 3.65349
# [2000]	training's rmse: 3.24777	valid_1's rmse: 3.65326
# [2100]	training's rmse: 3.23555	valid_1's rmse: 3.65304
# [2200]	training's rmse: 3.22367	valid_1's rmse: 3.6528
# [2300]	training's rmse: 3.21191	valid_1's rmse: 3.65262
# [2400]	training's rmse: 3.20022	valid_1's rmse: 3.65252
# [2500]	training's rmse: 3.18899	valid_1's rmse: 3.65243
# [2600]	training's rmse: 3.17786	valid_1's rmse: 3.65227
# [2700]	training's rmse: 3.16681	valid_1's rmse: 3.65232
# [2800]	training's rmse: 3.1563	valid_1's rmse: 3.65247
# [2900]	training's rmse: 3.14604	valid_1's rmse: 3.6525
# Early stopping, best iteration is:
# [2626]	training's rmse: 3.17454	valid_1's rmse: 3.65211
# 161
# fold n°4
# Training until validation scores don't improve for 300 rounds.
# [100]	training's rmse: 3.7387	valid_1's rmse: 3.6038
# [200]	training's rmse: 3.66076	valid_1's rmse: 3.57406
# [300]	training's rmse: 3.60528	valid_1's rmse: 3.55976
# [400]	training's rmse: 3.5632	valid_1's rmse: 3.55076
# [500]	training's rmse: 3.52896	valid_1's rmse: 3.54477
# [600]	training's rmse: 3.4988	valid_1's rmse: 3.54061
# [700]	training's rmse: 3.47317	valid_1's rmse: 3.53742
# [800]	training's rmse: 3.44989	valid_1's rmse: 3.53518
# [900]	training's rmse: 3.42801	valid_1's rmse: 3.53326
# [1000]	training's rmse: 3.40854	valid_1's rmse: 3.53151
# [1100]	training's rmse: 3.3894	valid_1's rmse: 3.53073
# [1200]	training's rmse: 3.37183	valid_1's rmse: 3.52973
# [1300]	training's rmse: 3.35506	valid_1's rmse: 3.52908
# [1400]	training's rmse: 3.33901	valid_1's rmse: 3.52872
# [1500]	training's rmse: 3.32438	valid_1's rmse: 3.52826
# [1600]	training's rmse: 3.30945	valid_1's rmse: 3.52818
# [1700]	training's rmse: 3.29527	valid_1's rmse: 3.5283
# [1800]	training's rmse: 3.28202	valid_1's rmse: 3.52795
# [1900]	training's rmse: 3.26901	valid_1's rmse: 3.52783
# [2000]	training's rmse: 3.25619	valid_1's rmse: 3.52806
# [2100]	training's rmse: 3.24384	valid_1's rmse: 3.52769
# [2200]	training's rmse: 3.23125	valid_1's rmse: 3.52797
# [2300]	training's rmse: 3.21948	valid_1's rmse: 3.52809
# [2400]	training's rmse: 3.20854	valid_1's rmse: 3.52776
# Early stopping, best iteration is:
# [2161]	training's rmse: 3.23614	valid_1's rmse: 3.52758
# 161
# fold n°5
# Training until validation scores don't improve for 300 rounds.
# [100]	training's rmse: 3.7208	valid_1's rmse: 3.7917
# [200]	training's rmse: 3.64411	valid_1's rmse: 3.75093
# [300]	training's rmse: 3.59077	valid_1's rmse: 3.72947
# [400]	training's rmse: 3.5494	valid_1's rmse: 3.71616
# [500]	training's rmse: 3.51541	valid_1's rmse: 3.70675
# [600]	training's rmse: 3.48544	valid_1's rmse: 3.70097
# [700]	training's rmse: 3.46	valid_1's rmse: 3.69638
# [800]	training's rmse: 3.43666	valid_1's rmse: 3.69255
# [900]	training's rmse: 3.4154	valid_1's rmse: 3.69021
# [1000]	training's rmse: 3.3953	valid_1's rmse: 3.68848
# [1100]	training's rmse: 3.37643	valid_1's rmse: 3.68683
# [1200]	training's rmse: 3.35878	valid_1's rmse: 3.6861
# [1300]	training's rmse: 3.34245	valid_1's rmse: 3.68609
# [1400]	training's rmse: 3.32681	valid_1's rmse: 3.68575
# [1500]	training's rmse: 3.31167	valid_1's rmse: 3.68515
# [1600]	training's rmse: 3.29699	valid_1's rmse: 3.68519
# [1700]	training's rmse: 3.28317	valid_1's rmse: 3.68526
# [1800]	training's rmse: 3.26949	valid_1's rmse: 3.68479
# [1900]	training's rmse: 3.25687	valid_1's rmse: 3.68492
# [2000]	training's rmse: 3.24446	valid_1's rmse: 3.68489
# [2100]	training's rmse: 3.23192	valid_1's rmse: 3.685
# Early stopping, best iteration is:
# [1812]	training's rmse: 3.26801	valid_1's rmse: 3.68473
# 161
# fold n°6
# Training until validation scores don't improve for 300 rounds.
# [100]	training's rmse: 3.70292	valid_1's rmse: 3.93474
# [200]	training's rmse: 3.62583	valid_1's rmse: 3.89267
# [300]	training's rmse: 3.57152	valid_1's rmse: 3.87174
# [400]	training's rmse: 3.52909	valid_1's rmse: 3.85953
# [500]	training's rmse: 3.49293	valid_1's rmse: 3.85329
# [600]	training's rmse: 3.46281	valid_1's rmse: 3.84888
# [700]	training's rmse: 3.43691	valid_1's rmse: 3.84594
# [800]	training's rmse: 3.41408	valid_1's rmse: 3.84418
# [900]	training's rmse: 3.39221	valid_1's rmse: 3.84293
# [1000]	training's rmse: 3.37185	valid_1's rmse: 3.84119
# [1100]	training's rmse: 3.35282	valid_1's rmse: 3.84038
# [1200]	training's rmse: 3.33504	valid_1's rmse: 3.83969
# [1300]	training's rmse: 3.31821	valid_1's rmse: 3.83935
# [1400]	training's rmse: 3.30251	valid_1's rmse: 3.83913
# [1500]	training's rmse: 3.28708	valid_1's rmse: 3.83857
# [1600]	training's rmse: 3.27216	valid_1's rmse: 3.83803
# [1700]	training's rmse: 3.25835	valid_1's rmse: 3.83806
# [1800]	training's rmse: 3.2445	valid_1's rmse: 3.83849
# [1900]	training's rmse: 3.23138	valid_1's rmse: 3.83829
# Early stopping, best iteration is:
# [1632]	training's rmse: 3.26779	valid_1's rmse: 3.83799
# 161
# fold n°7
# Training until validation scores don't improve for 300 rounds.
# [100]	training's rmse: 3.71435	valid_1's rmse: 3.8488
# [200]	training's rmse: 3.63817	valid_1's rmse: 3.80282
# [300]	training's rmse: 3.58442	valid_1's rmse: 3.78087
# [400]	training's rmse: 3.54166	valid_1's rmse: 3.7668
# [500]	training's rmse: 3.5076	valid_1's rmse: 3.75835
# [600]	training's rmse: 3.47811	valid_1's rmse: 3.75261
# [700]	training's rmse: 3.45314	valid_1's rmse: 3.74827
# [800]	training's rmse: 3.42987	valid_1's rmse: 3.74555
# [900]	training's rmse: 3.40929	valid_1's rmse: 3.74353
# [1000]	training's rmse: 3.38992	valid_1's rmse: 3.74172
# [1100]	training's rmse: 3.37197	valid_1's rmse: 3.7395
# [1200]	training's rmse: 3.35492	valid_1's rmse: 3.7381
# [1300]	training's rmse: 3.33854	valid_1's rmse: 3.73709
# [1400]	training's rmse: 3.32263	valid_1's rmse: 3.73668
# [1500]	training's rmse: 3.30811	valid_1's rmse: 3.7356
# [1600]	training's rmse: 3.29409	valid_1's rmse: 3.73473
# [1700]	training's rmse: 3.28071	valid_1's rmse: 3.73457
# [1800]	training's rmse: 3.26712	valid_1's rmse: 3.73401
# [1900]	training's rmse: 3.25421	valid_1's rmse: 3.73367
# [2000]	training's rmse: 3.24217	valid_1's rmse: 3.73343
# [2100]	training's rmse: 3.22992	valid_1's rmse: 3.73282
# [2200]	training's rmse: 3.21815	valid_1's rmse: 3.73236
# [2300]	training's rmse: 3.20635	valid_1's rmse: 3.73219
# [2400]	training's rmse: 3.19497	valid_1's rmse: 3.73188
# [2500]	training's rmse: 3.18375	valid_1's rmse: 3.73144
# [2600]	training's rmse: 3.17285	valid_1's rmse: 3.73098
# [2700]	training's rmse: 3.1623	valid_1's rmse: 3.73055
# [2800]	training's rmse: 3.15184	valid_1's rmse: 3.73063
# [2900]	training's rmse: 3.14156	valid_1's rmse: 3.7306
# [3000]	training's rmse: 3.13156	valid_1's rmse: 3.73015
# [3100]	training's rmse: 3.12172	valid_1's rmse: 3.72982
# [3200]	training's rmse: 3.11165	valid_1's rmse: 3.72954
# [3300]	training's rmse: 3.10181	valid_1's rmse: 3.72914
# [3400]	training's rmse: 3.09239	valid_1's rmse: 3.72901
# [3500]	training's rmse: 3.083	valid_1's rmse: 3.72892
# [3600]	training's rmse: 3.07366	valid_1's rmse: 3.72887
# [3700]	training's rmse: 3.06418	valid_1's rmse: 3.72907
# [3800]	training's rmse: 3.05539	valid_1's rmse: 3.72908
# Early stopping, best iteration is:
# [3525]	training's rmse: 3.08061	valid_1's rmse: 3.7287
# 161
# fold n°8
# Training until validation scores don't improve for 300 rounds.
# [100]	training's rmse: 3.72361	valid_1's rmse: 3.74644
# [200]	training's rmse: 3.64519	valid_1's rmse: 3.71137
# [300]	training's rmse: 3.59021	valid_1's rmse: 3.69412
# [400]	training's rmse: 3.54762	valid_1's rmse: 3.68391
# [500]	training's rmse: 3.51261	valid_1's rmse: 3.67755
# [600]	training's rmse: 3.48261	valid_1's rmse: 3.67315
# [700]	training's rmse: 3.45655	valid_1's rmse: 3.66965
# [800]	training's rmse: 3.43327	valid_1's rmse: 3.6675
# [900]	training's rmse: 3.4119	valid_1's rmse: 3.66596
# [1000]	training's rmse: 3.39234	valid_1's rmse: 3.66474
# [1100]	training's rmse: 3.37356	valid_1's rmse: 3.6636
# [1200]	training's rmse: 3.3565	valid_1's rmse: 3.66284
# [1300]	training's rmse: 3.34007	valid_1's rmse: 3.66261
# [1400]	training's rmse: 3.32452	valid_1's rmse: 3.66267
# [1500]	training's rmse: 3.3096	valid_1's rmse: 3.6629
# [1600]	training's rmse: 3.29482	valid_1's rmse: 3.66269
# [1700]	training's rmse: 3.28093	valid_1's rmse: 3.66257
# Early stopping, best iteration is:
# [1449]	training's rmse: 3.31716	valid_1's rmse: 3.66241
# 161
# fold n°9
# Training until validation scores don't improve for 300 rounds.
# [100]	training's rmse: 3.73128	valid_1's rmse: 3.67696
# [200]	training's rmse: 3.65416	valid_1's rmse: 3.64515
# [300]	training's rmse: 3.59885	valid_1's rmse: 3.6304
# [400]	training's rmse: 3.55695	valid_1's rmse: 3.61917
# [500]	training's rmse: 3.52302	valid_1's rmse: 3.61235
# [600]	training's rmse: 3.49356	valid_1's rmse: 3.60867
# [700]	training's rmse: 3.46774	valid_1's rmse: 3.6054
# [800]	training's rmse: 3.44502	valid_1's rmse: 3.6029
# [900]	training's rmse: 3.42354	valid_1's rmse: 3.60095
# [1000]	training's rmse: 3.403	valid_1's rmse: 3.59902
# [1100]	training's rmse: 3.38451	valid_1's rmse: 3.5978
# [1200]	training's rmse: 3.36731	valid_1's rmse: 3.59703
# [1300]	training's rmse: 3.3512	valid_1's rmse: 3.59616
# [1400]	training's rmse: 3.33575	valid_1's rmse: 3.59556
# [1500]	training's rmse: 3.32064	valid_1's rmse: 3.59512
# [1600]	training's rmse: 3.30618	valid_1's rmse: 3.59485
# [1700]	training's rmse: 3.29265	valid_1's rmse: 3.59453
# [1800]	training's rmse: 3.27927	valid_1's rmse: 3.5937
# [1900]	training's rmse: 3.26671	valid_1's rmse: 3.59348
# [2000]	training's rmse: 3.25419	valid_1's rmse: 3.59345
# [2100]	training's rmse: 3.24201	valid_1's rmse: 3.5936
# [2200]	training's rmse: 3.23017	valid_1's rmse: 3.59339
# Early stopping, best iteration is:
# [1940]	training's rmse: 3.26164	valid_1's rmse: 3.59326
# 161
# CV score: 3.66636

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('../5_submission/lgbm_importances.png')

# %%
lgbparam = {'num_leaves': 31,
#             'boosting_type': 'rf',
             'min_data_in_leaf': 30, 
             'objective':'regression',
             'max_depth': 12,
             'learning_rate': 0.01,
             "min_child_samples": 20,
             "boosting": "gbdt",
             "feature_fraction": 0.9,
             "bagging_freq": 1,
             "bagging_fraction": 0.9 ,
             "bagging_seed": 11,
             "metric": 'rmse',
             "lambda_l1": 0.1,
             "verbosity": -1,
             "nthread": 4,
             "random_state": 4590}

# %%
from sklearn.model_selection import RepeatedKFold
folds = RepeatedKFold(n_splits=10, n_repeats=2, random_state=4520)

oof_lgb = np.zeros(len(train))
predictions_lgb = np.zeros(len(test))
start = time.time()
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    print("fold n°{}".format(fold_))
    trn_data = lgb.Dataset(train.iloc[trn_idx][features], label=target.iloc[trn_idx], categorical_feature=categorical_feats)
    val_data = lgb.Dataset(train.iloc[val_idx][features], label=target.iloc[val_idx], categorical_feature=categorical_feats)

    num_round = 100000
    clf = lgb.train(lgbparam, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=3000, early_stopping_rounds = 300)
    oof_lgb[val_idx] = clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions_lgb += clf.predict(test[features], num_iteration=clf.best_iteration) / (5 * 2)

print("CV score: {:<8.5f}".format(mean_squared_error(oof_lgb, target)**0.5))
# Out:
# fold n°0
# /home/tung/miniconda3/envs/kaggle/lib/python3.7/site-packages/lightgbm/basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/tung/miniconda3/envs/kaggle/lib/python3.7/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [865]	training's rmse: 3.41921	valid_1's rmse: 3.57397
# fold n°1
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [869]	training's rmse: 3.38996	valid_1's rmse: 3.79444
# fold n°2
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1171]	training's rmse: 3.37391	valid_1's rmse: 3.43436
# fold n°3
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [2364]	training's rmse: 3.19371	valid_1's rmse: 3.64034
# fold n°4
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [944]	training's rmse: 3.37614	valid_1's rmse: 3.82319
# fold n°5
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1683]	training's rmse: 3.25785	valid_1's rmse: 3.82919
# fold n°6
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1138]	training's rmse: 3.36287	valid_1's rmse: 3.60383
# fold n°7
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1832]	training's rmse: 3.24656	valid_1's rmse: 3.70984
# fold n°8
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1497]	training's rmse: 3.31744	valid_1's rmse: 3.51497
# fold n°9
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1345]	training's rmse: 3.32252	valid_1's rmse: 3.70951
# fold n°10
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1130]	training's rmse: 3.35451	valid_1's rmse: 3.71293
# fold n°11
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [805]	training's rmse: 3.41155	valid_1's rmse: 3.74873
# fold n°12
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [2601]	training's rmse: 3.14964	valid_1's rmse: 3.70009
# fold n°13
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1079]	training's rmse: 3.37607	valid_1's rmse: 3.61406
# fold n°14
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1327]	training's rmse: 3.32383	valid_1's rmse: 3.73384
# fold n°15
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1243]	training's rmse: 3.34751	valid_1's rmse: 3.61715
# fold n°16
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [779]	training's rmse: 3.43215	valid_1's rmse: 3.56646
# fold n°17
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [946]	training's rmse: 3.38392	valid_1's rmse: 3.74921
# fold n°18
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [1504]	training's rmse: 3.31175	valid_1's rmse: 3.5598
# fold n°19
# Training until validation scores don't improve for 300 rounds.
# Early stopping, best iteration is:
# [2539]	training's rmse: 3.16517	valid_1's rmse: 3.65263
# CV score: 3.66615

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
sub_df = pd.DataFrame({"card_id":test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("submit_lgb.csv", index=False)

sub_df1 = pd.DataFrame({"card_id":test["card_id"].values})
sub_df1["target"] = predictions_lgb
sub_df1.to_csv("submit_lgb1.csv", index=False)

# %% [markdown]
# # Stacking

# %%
train_stack = np.vstack([oof,oof_lgb]).transpose()
test_stack = np.vstack([predictions,predictions_lgb]).transpose()

folds = RepeatedKFold(n_splits=5,n_repeats=1,random_state=4520)
oof_stack = np.zeros(train_stack.shape[0])
predictions_stack = np.zeros(test_stack.shape[0])

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_stack, target)):
    print("fold n°{}".format(fold_))
    trn_data, trn_y = train_stack[trn_idx], target.iloc[trn_idx].values
    val_data, val_y = train_stack[val_idx], target.iloc[val_idx].values

    print("-" * 10 + "Stacking " + str(fold_) + "-" * 10)
#     cb_model = CatBoostRegressor(iterations=3000, learning_rate=0.1, depth=8, l2_leaf_reg=20, bootstrap_type='Bernoulli',  eval_metric='RMSE', metric_period=50, od_type='Iter', od_wait=45, random_seed=17, allow_writing_files=False)
#     cb_model.fit(trn_data, trn_y, eval_set=(val_data, val_y), cat_features=[], use_best_model=True, verbose=True)
    clf = BayesianRidge()
    clf.fit(trn_data, trn_y)
    
    oof_stack[val_idx] = clf.predict(val_data)
    predictions_stack += clf.predict(test_stack) / 5


np.sqrt(mean_squared_error(target.values, oof_stack))
# Out:
# fold n°0
# ----------Stacking 0----------
# fold n°1
# ----------Stacking 1----------
# fold n°2
# ----------Stacking 2----------
# fold n°3
# ----------Stacking 3----------
# fold n°4
# ----------Stacking 4----------
# /home/tung/miniconda3/envs/kaggle/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/tung/miniconda3/envs/kaggle/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/tung/miniconda3/envs/kaggle/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/tung/miniconda3/envs/kaggle/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/tung/miniconda3/envs/kaggle/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 3.6641954935966408

# %%
sample_submission = pd.read_csv('../1_rawdata/sample_submission.csv')
sample_submission['target'] = predictions_stack
sample_submission.to_csv('../5_submission/Bayesian_Ridge_Stacking.csv', index=False)

# %%
sample_submission = pd.read_csv('../1_rawdata/sample_submission.csv')
sample1 = pd.read_csv("../5_submission/3.695.csv")
sample2 = pd.read_csv("../5_submission/combining_submission (1).csv")
sample_submission['target'] = predictions * 0.5 + predictions_lgb * 0.5
sample_submission.to_csv("../5_submission/CV3665_LB3689_170219_Blend1.csv", index = False)
sample_submission['target'] = sample_submission['target'] * 0.2 + sample1['target'] * 0.2 + sample2['target'] * 0.6
sample_submission.to_csv('../5_submission/CV3665_LB3689_170219_Blend2.csv', index=False)
